# %% [markdown]
# # IRAF Terminal Capture Notebook
# This notebook documents an IRAF terminal session, explaining each step of the workflow.
# Use it to convert terminal-only processing into a reproducible pipeline.

# %% [markdown]
# ## 1. Overview
# - What dataset you're using (telescope, date, filter)
# - What you're doing today (star picking, running `daofind`, preparing for subtraction)

# %% [markdown]
# ## 2. Raw IRAF Commands (Copied from terminal)
# Paste your raw terminal transcript here.
# This should include the exact commands you ran and their outputs.

# %%
# Example placeholder
# Copy-paste terminal content below as a multiline string for record-keeping.
iraf_log = """
# e.g.
cl> display science.fits 1
cl> daofind science.fits output=stars.coo fwhmpsf=3.0 sigma=10.0 threshold=5.0
"""

# %% [markdown]
# ## 3. Commentary / Explanation
# Explain what each IRAF step accomplishes and what choices you made (e.g., star selection criteria, FWHM estimates).

# %% [markdown]
# ## 4. Link to `iraf_cmds.cl`
# Document how the IRAF script relates to your manual session.
